# %% [markdown]
# <img src= "iteso.jpg">
#
# <div style="text-align:center"><span style="color:#170D5D; font-family:Georgia; font-size:3.1em; LINE-HEIGHT:80px"> Microestructura y sistemas de trading </span></div>
#
# ><b> <p style = "font-family: Palatino; font-size:1.7em; color: #170D5D;" > Laboratorio 1: Inversión de Capital </p> <b/>
# ><br />
# >
# ><b> <p style = "font-family: Palatino; font-size:1.7em; color: #170D5D;" > Alumno: Araceli Soledad Castillo Fuhr  </p> <b/>
# ><br />
# >
# ><b> <p style = "font-family: Palatino; font-size:1.7em; color: #170D5D;" > Expediente: if708243 </p> <b/>
# ><br />
# >

# %% [markdown]
# ## <font color= #170D5D> <font size = 5> Abstract </font>
#
# <font color= #170D5D> <font size = 2> Este documento fue elaborado por Araceli Soledad Castillo Fuhr, como un trabajo parcial para la materia de Microestructura y Sistemas de Trading - ITE1731, la cual es parte del curriculum de la licenciatura en Ingeniería Financiera, ofertada por la universidad ITESO. En el presente trabajo se plantea la respuesta a la siguiente pregunta: ¿Qué estrategia de inversión propondrías si tu trabajo fuera administrar 1 Millón de pesos?</font>

# %% [markdown]
# <font color= #6B6B6B> <font size = 6> 0. Librerías y Dependencias </font>¶

# %% [markdown]
# <font color= #6B6B6B> <font size = 5> 0.1 Librerías </font> <font color= #555555>
# Para correr este notebook es necesario tener instaladas y/o en el archivo requirements.txt las siguientes librerías :
#
# - pandas>=1.1.1
#
# - numpy>=1.19.1
#
# - jupyter>=1.0.0
#
# - yfinance>=0.1.54

# %%
import pandas as pd

# %% [markdown]
# <font color= #6B6B6B> <font size = 5> 0.2 Dependencias </font> <font color= #555555>
#
# Para correr este notebook es necesario contar con los siguientes archivos y dependencias externas:
#
# files/precios.csv : Precios históricos
# files/datos.txt : Otros datos históricos

# %% [markdown]
# <font color= #6B6B6B> <font size = 6> 1. Introducción </font>

# %% [markdown]
# <font color= #6B6B6B> <font size = 6> 2. Objetivos </font>

# %% [markdown]
# <font color= #6B6B6B> <font size = 6> 3. Datos </font>

# %% [markdown]
# #### En esta sección es opcional incluir código para mostrar/visualizar
# #### los datos con los que se trabajó en el laboratorio

# %% [markdown]
# <font color= #170D5D> <font size = 2> </font>

# %%
import data as dt
# Out:
# [*********************100%***********************]  39 of 39 completed

# %%
import functions as ft

# %%
# Obtener los archivos que se van a utilizar

files = dt.files
files[:5]
# Out:
# ['NAFTRAC_210820.csv',
#  'NAFTRAC_280218.csv',
#  'NAFTRAC_280219.csv',
#  'NAFTRAC_280220.csv',
#  'NAFTRAC_280318.csv']

# %%
# Obtener lista de los archivos por fecha

files_date = dt.files_date
files_date[:5]
# Out:
# [datetime.date(2018, 1, 30),
#  datetime.date(2018, 1, 31),
#  datetime.date(2018, 2, 28),
#  datetime.date(2018, 3, 28),
#  datetime.date(2018, 4, 30)]

# %%
# Obtener lista de DataFrames de los documentos leídos

lista_df = dt.lista_df
lista_df[1][:3]
# Out:
#      Ticker                      Nombre Clase de activo  Peso (%)  Precio  \
# 0      AMXL             AMERICA MOVIL L          Equity    0.1406   17.34
# 1  FEMSAUBD  FOMENTO ECONOMICO MEXICANO          Equity    0.1297  174.52
# 2  GFNORTEO         GPO FINANCE BANORTE          Equity    0.0957  113.16
#
#          Acciones  Valor de mercado     Valor nominal  \
# 0  336,238,294.00  5,830,372,017.96  5,830,372,017.96
# 1   30,801,589.00  5,375,493,312.28  5,375,493,312.28
# 2   35,050,687.00  3,966,335,740.92  3,966,335,740.92
#
#                          Sector Unnamed: 9          ISIN  \
# 0            Telecomunicaciones    2667470  MXP001691213
# 1  Productos básicos de consumo    2242059  MXP320321310
# 2                   Financieros    2421041  MXP370711014
#
#             Bolsa de valores Ubicación Moneda Mercado de divisas  \
# 0  Bolsa Mexicana De Valores    México    MXN                MXN
# 1  Bolsa Mexicana De Valores    México    MXN                MXN
# ...

# %%
# Obtener un vector de tickers de cada uno de los DataFrames

g_tickers = dt.g_tickers
g_tickers[:5]
# Out:
# ['AC.MX', 'ALFAA.MX', 'ALPEKA.MX', 'ALSEA.MX', 'AMXL.MX']

# %%
# Obtener datos descargados de Yahoo Finance para hacer los calculos

descarga = dt.descarga
descarga[:5]
# Out:
# Date                  2018-01-31  2018-02-01  2018-02-02  2018-02-06  \
# GENTERA.MX Open        16.700001   16.830000   16.770000   15.930000
#            High        16.900000   16.969999   16.889999   16.469999
#            Low         16.510000   16.570000   16.209999   15.820000
#            Close       16.870001   16.690001   16.250000   15.990000
#            Adj Close   15.746818   15.578800   15.168095   14.925406
#
# Date                  2018-02-07  2018-02-08  2018-02-09  2018-02-12  \
# GENTERA.MX Open        16.000000   15.910000   15.500000   15.490000
#            High        16.219999   16.049999   15.810000   15.690000
#            Low         15.760000   15.520000   14.950000   15.230000
#            Close       16.190001   15.660000   15.460000   15.580000
#            Adj Close   15.112091   14.617377   14.430694   14.542704
#
# Date                  2018-02-13  2018-02-14  2018-02-15  2018-02-16  \
# ...

# %%
# Obtener los datos correspondientes a la fecha de inversion necesarios para hacer los calculos

f_ticker = dt.f_ticker
pesos = dt.pesos
V_port = dt.V_port
Comision = dt.Comision

print(f_ticker[:5])
print(pesos[:5])
print(V_port)
print(Comision)
# Out:
# ['AMXL.MX', 'FEMSAUBD.MX', 'GFNORTEO.MX', 'WALMEX.MX', 'GMEXICOB.MX']
# AMXL.MX        0.1331
# FEMSAUBD.MX    0.1269
# GFNORTEO.MX    0.0951
# WALMEX.MX      0.0760
# GMEXICOB.MX    0.0754
# Name: Peso (%), dtype: float64
# 1000000
# 0.00125

# %% [markdown]
# <font color= #6B6B6B> <font size = 6> 4. Procesos </font>

# %% [markdown]
# #### aqui se incluye toda la secuencia de main.py.
# #### tomando los pasos en los que fuiste haciendo todos los calculos
# #### y poniendo cada uno como un subtitulo con markdown de nivel dos, así ## subtitulo de mi paso

# %% [markdown]
# <font color= #6B6B6B> <font size = 5> 4.1. Inversión Pasiva </font>

# %% [markdown]
# ## <font color= #555555> <font size = 4> Calcular el valor de la posicion del portafolio de inversion en la primera fecha </font>

# %%
# -- --------------------------------------------------------------------------------------------------- -Paso 1.7 - #
# -- --------------------------------------------------------------------------------------------------- -Paso 1.8 - #
# -- --------------------------------------------------------------------------------------------------- -Paso 1.9 - #
# Calcular el valor de la posicion del portafolio para inversion pasiva en la primera fecha
# Calcular el valor del portafolio para cada cierre de mes en la inversion pasiva
valores_port = ft.valores_port
valores_port[:5]
# Out:
# [1000000,
#  955709.4598293304,
#  900234.7662582397,
#  875809.6425533295,
#  918675.9290857315]

# %% [markdown]
# ## <font color= #555555> <font size = 4> Calcular los valores necesarios para el DataFrame, como los rendimientos </font>

# %%
# -- --------------------------------------------------------------------------------------------------- -Paso 1.10 - #
# Obtener los valores de rendimientos
rendimientos = ft.rendimientos
rendimientos[:5]
# Out:
#           0
# 1 -0.001195
# 2 -0.055541
# 3 -0.025892
# 4  0.046649
# 5 -0.074104

# %%
# -- --------------------------------------------------------------------------------------------------- -Paso 1.11 - #
# Agregar una fecha antes del inicio de la inversion
dt.files_date[:5]
# Out:
# [datetime.date(2018, 1, 30),
#  datetime.date(2018, 1, 31),
#  datetime.date(2018, 2, 28),
#  datetime.date(2018, 3, 28),
#  datetime.date(2018, 4, 30)]

# %%
# -- --------------------------------------------------------------------------------------------------- -Paso 1.11 - #
# -- --------------------------------------------------------------------------------------------------- -Paso 1.12 - #
ft.df_pasiva[:6]
# Out:
#                    capital      rend  rend_acum
# timestamp
# 2018-01-30  1000000.000000  0.000000   0.000000
# 2018-01-31   955709.459829 -0.001195  -0.001195
# 2018-02-28   900234.766258 -0.055541  -0.056736
# 2018-03-28   875809.642553 -0.025892  -0.082628
# 2018-04-30   918675.929086  0.046649  -0.035979
# 2018-05-31   847404.376017 -0.074104  -0.110083

# %% [markdown]
# <font color= #6B6B6B> <font size = 6> 5. Conclusiones </font>

# %% [markdown]
# #### en esta seccion es opcional incluir algun codigo para mostrar
# #### visualmente algun concepto o hallazgo relevante como conclusion
